# %% [markdown]
# ### Getting flights data for the cities
# Gans wants to know when the flights arrive to the city of interest to be able to predict the escooter usage. To obtains flights arrival times for the day of interest, I use the AeroDataBox api ([API Documentation](https://rapidapi.com/aedbx-aedbx/api/aerodatabox/details)). This code will generate two SQL tables:
#
# 1. **Airports icao codes**: A function *icao_airport_codes(latitudes, longitudes)* will take in city coordinates and find airports closer to the selected cities. Importantly, it will store city icao codes that will be used to obtain the flights data.
# 2. **Flights data**: A function *get_arrival_data(icao_list)* will take in airport ICAO codes and produce the following flights data columns. Notably, the flight data for the next day will be produced to be able to forecast e-scooter traffic.
# - *"arrival_airport_icao"* - Arrival airport's ICAO code
# - "departure_airport_icao"* - Departure airport's ICAO code
# - *"departure_airport_name"* - Departure airport's name
# - *"scheduled_arrival_time"* - Scheduled arrival time
# - *"flight_number"* - Flight number
# - *"data_retrieved_at"* - Date of the data retrieval

# %% [markdown]
# #### Import libraries and cities df

# %%
import pandas as pd
import requests
import sqlalchemy

import datetime
from pytz import timezone
from datetime import datetime, timedelta

import warnings
warnings.filterwarnings('ignore')

# Get the api key
from keys import AeroDatabox, MySQL_bootcamp

# %%
df_cities = pd.read_csv("data/df_sql_city_id.csv")
df_cities
# Out:
#           City country_2c  latitude  longitude  is_capital       Country  \
# 0       Berlin         DE   52.5167    13.3833        True       Germany
# 1      Hamburg         DE   53.5500    10.0000       False       Germany
# 2       Munich         DE   48.1372    11.5755       False       Germany
# 3      Cologne         DE   50.9422     6.9578       False       Germany
# 4        Paris         FR   48.8566     2.3522        True        France
# 5         Nice         FR   43.7034     7.2663       False        France
# 6         Rome         IT   41.8931    12.4828        True         Italy
# 7        Milan         IT   45.4669     9.1900       False         Italy
# 8       Warsaw         PL   52.2167    21.0333        True        Poland
# 9    Barcelona         ES   41.3825     2.1769       False         Spain
# 10      Madrid         ES   40.4189    -3.6919        True         Spain
# 11     Sevilla         ES   37.3828    -5.9731       False         Spain
# 12      London         GB   51.5072    -0.1275        True       England
# 13  Birmingham         GB   52.4800    -1.9025       False       England
# 14  Manchester         GB   53.4794    -2.2453       False       England
# 15       Leeds         GB   53.7997    -1.5492       False       England
# 16   Newcastle         GB   55.0077    -1.6578       False       England
# 17   The Hague         NL   52.0800     4.2700        True   Netherlands
# 18   Amsterdam         NL   52.3500     4.9166        True   Netherlands
# 19   Rotterdam         NL   51.9200     4.4800       False   Netherlands
#
#     Elevation (in m)  Population  city_id  Elevation
# 0               34.0     3576873        1         34
# 1               23.0     1945532        2         23
# 2              520.0     1512491        3        520
# 3               37.0     1073096        4         37
# 4               35.0     2102650        5         35
# 5               10.0      348085        6         10
# 6               21.0     2860009        7         21
# 7              120.0     1371498        8        120
# 8              100.0     1863056        9        100
# 9               12.0     1620343       10         12
# 10             650.0     3223334       11        650
# 11               7.0      684234       12          7
# 12              11.0     8799800       13         11
# 13             140.0     1142494       14        140
# 14              38.0      549853       15         38
# 15              10.0      536280       16         10
# 16              30.0      168873       17         30
# 17               1.0      549163       18          1
# 18              -2.0      921402       19         -2
# 19               2.0      664311       20          2

# %% [markdown]
# #### Get airport icao codes for selected cities

# %%
# Creating a function to get airports for the city
def icao_airport_codes(latitudes, longitudes):
  #assert len(latitudes) == len(longitudes)
  list_for_df = []
  for i in range(len(latitudes)):
    url = "https://aerodatabox.p.rapidapi.com/airports/search/location"
    querystring = {"lat":latitudes[i],"lon":longitudes[i],"radiusKm":"50","limit":"5","withFlightInfoOnly":"true"}
    headers = {
      "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com",
      "X-RapidAPI-Key": AeroDatabox
    }
    response = requests.request("GET", url, headers=headers, params=querystring)
    list_for_df.append(pd.json_normalize(response.json()['items']))
  return pd.concat(list_for_df, ignore_index=True)

df_airports = pd.DataFrame(icao_airport_codes(df_cities["latitude"], df_cities["longitude"]))
df_airports
# Out:
#     icao iata                              name                    shortName  \
# 0   EDDB  BER                Berlin Brandenburg                  Brandenburg
# 1   EDDH  HAM                          Hamburg                       Hamburg
# 2   EDDM  MUC                           Munich                        Munich
# 3   EDDK  CGN                      Cologne Bonn                         Bonn
# 4   EDDL  DUS            Duesseldorf Düsseldorf                   Düsseldorf
# 5   LFPB  LBG                 Paris -Le Bourget                  -Le Bourget
# 6   LFPO  ORY                       Paris -Orly                        -Orly
# 7   LFPG  CDG           Paris Charles de Gaulle            Charles de Gaulle
# 8   LFMN  NCE                 Nice -Côte d'Azur                 -Côte d'Azur
# 9   LIRA  CIA       Roma Ciampino–G. B. Pastine       Ciampino–G. B. Pastine
# 10  LIRF  FCO  Rome Leonardo da Vinci–Fiumicino  Leonardo da Vinci–Fiumicino
# 11  LIML  LIN                      Milan Linate                       Linate
# 12  LIMC  MXP                    Milan Malpensa                     Malpensa
# 13  LIME  BGY             Bergamo Orio al Serio                Orio al Serio
# 14  EPWA  WAW                     Warsaw Chopin                       Chopin
# 15  EPMO  WMI                     Warsaw Modlin                       Modlin
# 16  LEBL  BCN                        Barcelona                     Barcelona
# 17  LEMD  MAD     Madrid Adolfo Suárez –Barajas       Adolfo Suárez –Barajas
# 18  LEZL  SVQ                   Seville Sevilla                      Sevilla
# 19  EGLC  LCY                       London City                         City
# 20  EGLL  LHR                   London Heathrow                     Heathrow
# 21  EGKR  KRH                 Redhill Aerodrome                    Aerodrome
# 22  EGBB  BHX                       Birmingham                    Birmingham
# 23  EGCC  MAN                       Manchester                    Manchester
# 24  EGGP  LPL             Liverpool John Lennon                  John Lennon
# 25  EGNM  LBA                    Leeds Bradford                     Bradford
# 26  EGNT  NCL     Newcastle upon Tyne Newcastle                    Newcastle
# 27  EHRD  RTM               Rotterdam The Hague                    The Hague
# 28  EHAM  AMS                Amsterdam Schiphol                     Schiphol
# 29  EHAM  AMS                Amsterdam Schiphol                     Schiphol
# 30  EHRD  RTM               Rotterdam The Hague                    The Hague
# 31  EHAM  AMS                Amsterdam Schiphol                     Schiphol
#
#        municipalityName countryCode  location.lat  location.lon
# 0                Berlin          DE      52.35139     13.493889
# 1               Hamburg          DE      53.63040      9.988229
# 2                Munich          DE      48.35380     11.786100
# 3               Cologne          DE      50.86590      7.142739
# 4           Duesseldorf          DE      51.28950      6.766779
# 5                 Paris          FR      48.96940      2.441390
# 6                 Paris          FR      48.72530      2.359440
# 7                 Paris          FR      49.01280      2.549999
# 8                  Nice          FR      43.65840      7.215869
# 9                  Roma          IT      41.79940     12.594900
# 10                 Rome          IT      41.80450     12.250800
# 11                Milan          IT      45.44510      9.276740
# 12                Milan          IT      45.63060      8.728110
# 13              Bergamo          IT      45.67390      9.704170
# 14               Warsaw          PL      52.16570     20.967100
# 15               Warsaw          PL      52.45110     20.651800
# 16            Barcelona          ES      41.29710      2.078459
# 17               Madrid          ES      40.49360     -3.566760
# 18              Seville          ES      37.41800     -5.893109
# 19               London          GB      51.50530      0.055277
# 20               London          GB      51.47060     -0.461941
# 21              Redhill          GB      51.21360     -0.138611
# 22           Birmingham          GB      52.45390     -1.748029
# 23           Manchester          GB      53.35370     -2.274950
# 24            Liverpool          GB      53.33360     -2.849720
# 25                Leeds          GB      53.86590     -1.660570
# 26  Newcastle upon Tyne          GB      55.03750     -1.691669
# 27            Rotterdam          NL      51.95690      4.437220
# 28            Amsterdam          NL      52.30860      4.763889
# 29            Amsterdam          NL      52.30860      4.763889
# 30            Rotterdam          NL      51.95690      4.437220
# 31            Amsterdam          NL      52.30860      4.763889

# %% [markdown]
# Restrict the dataframe to preferred information

# %%
df_airports = df_airports[["icao", "municipalityName"]]

# %% [markdown]
# #### Merge airports dataframe with cities df
# First let's rename cities to match city_df city names

# %%
df_airports.loc[df_airports["municipalityName"]=="Newcastle upon Tyne", "municipalityName"]="Newcastle"
df_airports.loc[df_airports["municipalityName"]=="Seville", "municipalityName"]="Sevilla"
df_airports.iloc[27, df_airports.columns.get_loc('municipalityName')] = "The Hague"

# %% [markdown]
# Merge two dataframes and restrict the merged df to contains needed columns

# %%
df_airports_merged = df_cities.merge(df_airports, how="left", left_on="City", right_on="municipalityName")
df_airports_merged = df_airports_merged[["city_id", "icao"]]
df_airports_merged
# Out:
#     city_id  icao
# 0         1  EDDB
# 1         2  EDDH
# 2         3  EDDM
# 3         4  EDDK
# 4         5  LFPB
# 5         5  LFPO
# 6         5  LFPG
# 7         6  LFMN
# 8         7  LIRF
# 9         8  LIML
# 10        8  LIMC
# 11        9  EPWA
# 12        9  EPMO
# 13       10  LEBL
# 14       11  LEMD
# 15       12  LEZL
# 16       13  EGLC
# 17       13  EGLL
# 18       14  EGBB
# 19       15  EGCC
# 20       16  EGNM
# 21       17  EGNT
# 22       18  EHRD
# 23       19  EHAM
# 24       19  EHAM
# 25       19  EHAM
# 26       20  EHRD

# %% [markdown]
# #### Create airports table in SQL DB

# %%
# Create a connecting link
schema = "gans_cities"
host = "127.0.0.1"
user = "root"
password = MySQL_bootcamp
port = 3306

connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{schema}'

# %%
df_airports_merged.to_sql('airports',
                  if_exists='append',
                  con=connection_string,
                  index=False)
# Out:
# 27

# %% [markdown]
# #### Save the airports df

# %%
df_airports_merged.to_csv("data/df_airports_merged.csv", sep=',', index=False, encoding='utf-8')

# %% [markdown]
# #### Get flights data

# %%
# Create a function to get arrival info at the selected airport
def get_arrival_data(icao_list):
  api_key = AeroDatabox

  berlin_timezone = timezone('Europe/Berlin')
  today = datetime.now(berlin_timezone).date()
  tomorrow = (today + timedelta(days=1))

  flight_items = []

  for icao in icao_list:
    # the api can only make 12 hour calls, therefore, 2 12 hour calls make a full day
    # using the nested lists below we can make a morning call and extract the data
    # then make an afternoon call and extract the data
    times = [["00:00","11:59"],
             ["12:00","23:59"]]

    for time in times:
      url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{icao}/{tomorrow}T{time[0]}/{tomorrow}T{time[1]}"

      querystring = {"withLeg":"true",
                    "direction":"Arrival",
                    "withCancelled":"false",
                    "withCodeshared":"true",
                    "withCargo":"false",
                    "withPrivate":"false"}

      headers = {
          'x-rapidapi-host': "aerodatabox.p.rapidapi.com",
          'x-rapidapi-key': api_key
          }

      response = requests.get(url, headers=headers, params=querystring)

      flights_json = response.json()

      retrieval_time = datetime.now(berlin_timezone).strftime("%Y-%m-%d %H:%M:%S")

      for item in flights_json["arrivals"]:
        flight_item = {
            "arrival_airport_icao": icao,
            "departure_airport_icao": item["departure"]["airport"].get("icao", None),
            "departure_airport_name": item["departure"]["airport"].get("name", None),
            "scheduled_arrival_time": item["arrival"]["scheduledTime"].get("local", None),
            "flight_number": item.get("number", None),
            "data_retrieved_at": retrieval_time
        }

        flight_items.append(flight_item)

  flights_df = pd.DataFrame(flight_items)
  flights_df["scheduled_arrival_time"] = flights_df["scheduled_arrival_time"].str[:-6]
  flights_df["scheduled_arrival_time"] = pd.to_datetime(flights_df["scheduled_arrival_time"])
  flights_df["data_retrieved_at"] = pd.to_datetime(flights_df["data_retrieved_at"])

  return flights_df

# %% [markdown]
# #### Get tomorrow's flights arrival data for London Heathrow airport

# %%
df_airport_london = df_airports.loc[df_airports["icao"]=="EGLL", "icao"]
# Specify the airport code ("EGLL") as a list
airport_codes = list(df_airport_london.values)
flights_df = get_arrival_data(airport_codes)
flights_df
# Out:
#      arrival_airport_icao departure_airport_icao departure_airport_name  \
# 0                    EGLL                   FACT              Cape Town
# 1                    EGLL                   DNMM                  Lagos
# 2                    EGLL                   FACT              Cape Town
# 3                    EGLL                   FACT              Cape Town
# 4                    EGLL                   DNMM                  Lagos
# ...                   ...                    ...                    ...
# 2306                 EGLL                   LPPT                 Lisbon
# 2307                 EGLL                   LPPT                 Lisbon
# 2308                 EGLL                   LTFM               Istanbul
# 2309                 EGLL                   OTHH                   Doha
# 2310                 EGLL                   OTHH                   Doha
#
#      scheduled_arrival_time flight_number   data_retrieved_at
# 0       2024-02-16 04:45:00       AA 7109 2024-02-15 13:58:49
# 1       2024-02-16 04:50:00       AY 5904 2024-02-15 13:58:49
# 2       2024-02-16 04:45:00       AY 5948 2024-02-15 13:58:49
# 3       2024-02-16 04:45:00         BA 58 2024-02-15 13:58:49
# 4       2024-02-16 04:50:00         BA 74 2024-02-15 13:58:49
# ...                     ...           ...                 ...
# 2306    2024-02-16 22:40:00       TP 1366 2024-02-15 13:58:50
# 2307    2024-02-16 22:40:00       UA 6864 2024-02-15 13:58:50
# 2308    2024-02-16 22:15:00       UA 6916 2024-02-15 13:58:50
# 2309    2024-02-16 22:10:00       WB 1402 2024-02-15 13:58:50
# 2310    2024-02-16 22:10:00       WY 6433 2024-02-15 13:58:50
#
# [2311 rows x 6 columns]

# %%
flights_df["scheduled_arrival_time"].min()
# Out:
# Timestamp('2024-02-16 04:45:00')

# %%
flights_df["scheduled_arrival_time"].max()
# Out:
# Timestamp('2024-02-16 22:55:00')

# %% [markdown]
# #### Read airports table from SQL DB to get airport_id

# %%
df_airports_sql = pd.read_sql("airports", con=connection_string)
df_airports_sql=df_airports_sql[['airport_id', 'icao']]
df_airports_sql
# Out:
#     airport_id  icao
# 0            1  EDDB
# 1            2  EDDH
# 2            3  EDDM
# 3            4  EDDK
# 4            5  LFPB
# 5            6  LFPO
# 6            7  LFPG
# 7            8  LFMN
# 8            9  LIRF
# 9           10  LIML
# 10          11  LIMC
# 11          12  EPWA
# 12          13  EPMO
# 13          14  LEBL
# 14          15  LEMD
# 15          16  LEZL
# 16          17  EGLC
# 17          18  EGLL
# 18          19  EGBB
# 19          20  EGCC
# 20          21  EGNM
# 21          22  EGNT
# 22          23  EHRD
# 23          24  EHAM
# 24          25  EHAM
# 25          26  EHAM
# 26          27  EHRD

# %% [markdown]
# #### Merge airports table from SQL DB to get airport_id

# %%
flights_merged_df= flights_df.merge(df_airports_sql, how="left", left_on="arrival_airport_icao", right_on="icao")
flights_merged_df.columns
# Out:
# Index(['arrival_airport_icao', 'departure_airport_icao',
#        'departure_airport_name', 'scheduled_arrival_time', 'flight_number',
#        'data_retrieved_at', 'airport_id', 'icao'],
#       dtype='object')

# %%
flights_merged_df = flights_merged_df.drop("icao", axis=1)

# %% [markdown]
# #### Save the flights df

# %%
flights_merged_df.to_csv("data/df_flight_arrivals.csv", sep=',', index=False, encoding='utf-8')

# %% [markdown]
# #### Create a flights table in SQL DB

# %%
flights_merged_df.to_sql('flights',
                  if_exists='append',
                  con=connection_string,
                  index=False)
# Out:
# 2311
